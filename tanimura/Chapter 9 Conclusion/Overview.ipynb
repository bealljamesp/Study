# %% [markdown]
# Chapter 2: Data Cleaning, Type Casting, String Stripping, and NULL Coalescing.
#
# Chapter 3: Time-Series Truncation, Moving Averages, and Period-over-Period Lags.
#
# Chapter 4: Cohort Anchoring, Relative Period Indexing, and Retention Pivoting.
#
# Chapter 5: Regex Extraction, Unstructured Text Parsing, and Fuzzy Categorization.
#
# Chapter 6: Parametric $Z$-Score Calculation, Rolling Anomaly Thresholds, and Sequence Gaps.
#
# Chapters 7 & 8: Post-Exposure A/B Testing, CTE Pipeline Architecture, and Fan-Out Prevention.

# %% [markdown]
# For a high-level quantitative analyst, risk quant, or senior analytics professional, a resume block dedicated to SQL should never list basic syntax like GROUP BY, JOINs, or WHERE. Hiring managers already expect anyone with a quantitative degree to know basic database syntax.
#
# Instead, your resume should showcase data architecture fluency, analytical scale, pipeline modularity, and database performance optimization. You want to communicate that you write production-grade, vectorized, set-based SQL that runs efficiently at hardware speed on modern database clusters (DuckDB, Snowflake, PostgreSQL, BigQuery).

# %% [markdown]
# 1. Resume Section Title & Layout Options
#
# Depending on your overall resume structure, place this as a dedicated Core Competencies / Technical Expertise block or as a targeted Database & Data Architecture section.
#
# Option A: High-Impact Technical Skills Block (Categorized)SQL & Data Architecture: High-Performance Vectorized Querying (DuckDB, PostgreSQL), Multi-Period Cohort & Retention Analysis, Rolling Window Statistics & Anomaly Detection ($Z$-Score/IQR), Event-Driven Time-Series Indexing, Complex CTE Pipeline Architecture, A/B Testing Exposure Window Modeling, Query Execution Plan Optimization (WHERE Pushdown, Fan-Out Prevention).
#
# Option B: Dedicated Bullet Point Block (Action-Oriented Impact)
#
# If you are writing a bulleted "Technical Competencies" section or updating your experience bullets to reflect SQL mastery:
#
# Analytical Pipeline Architecture: Engineered modular, multi-step Common Table Expression (CTE) execution graphs in SQL/DuckDB to transform raw event streams into clean, vectorized analytical matrices.
#
# Time-Series & Volatility Modeling: Developed window-aggregated time-series queries to compute rolling moving averages, lag metrics (MoM/YoY growth), and real-time statistical anomaly detection bounds ($Z$-score, IQR dispersion).
#
# Cohort Analysis & Retention Frameworks: Built triangular cohort retention matrices by indexing entity activity relative to fixed origin dates ($t_0$) and calculating elapsed vintage age across dynamic time horizons.
#
# Performance Optimization & Scalability: Optimized complex multi-table joins and data models by enforcing early filter pushdowns, eliminating join fan-outs through pre-aggregation, and minimizing full-table memory scans.
#
# Experimental Evaluation & Unstructured Parsing: Structured post-exposure experimental analysis frameworks (A/B testing) and applied regular expression extraction engines (REGEXP_EXTRACT, fuzzy matching) to standardize unstructured text logs.

# %% [markdown]
# | Book Concept (Tanimura)            | What to Call It on a Resume                          | Industry Value / Signal                                                                                                                |
# | :--------------------------------- | :--------------------------------------------------- | :------------------------------------------------------------------------------------------------------------------------------------- |
# | **Chapter 2 (Cleaning & Casting)** | Unstructured Data Standardisation & Type Enforcement | Demonstrates ability to handle messy, low-quality production event streams without breaking downstream pipelines.                      |
# | **Chapter 3 (Time Series)**        | Temporal Bucketing & Rolling Window Analytics        | Shows capability to compute continuous time-series metrics, volatility bounds, and period-over-period growth directly in the database. |
# | **Chapter 4 (Cohorts)**            | Vintage Age Indexing & Survival/Retention Modeling   | Direct signal for risk modeling (credit default curves, policyholder churn, lifetime value $LTV$).                                     |
# | **Chapter 5 (Regex/Text)**         | Regex Pattern Extraction & Fuzzy Entity Resolution   | Proves you can extract actionable quantitative metrics out of un-categorized log files and free-text fields.                           |
# | **Chapter 6 (Anomalies)**          | Parametric & Non-Parametric Outlier Detection        | Demonstrates automated data-quality monitoring and real-time risk alert generation at the database layer.                              |
# | **Chapters 7 & 8 (CTEs/Joins)**    | Modular CTE DAG Architecture & Fan-Out Prevention    | Signals that you write readable, production-grade, maintainable SQL code that doesn't crash server clusters or distort aggregates.     |

# %% [markdown]
# **CORE COMPETENCIES & TECHNICAL SKILLS**
#
# - **Quantitative Scripting & Statistical Modeling:** Python 3.12+ (NumPy, SciPy, Pandas, Polars), GLMs & Multivariate Regression, Time-Series Econometrics (ARIMA/GARCH), Hypothesis Testing, Non-Parametric Methods, Causal Inference, C-Array / SIMD Vectorization.
# - **Database Architecture & Advanced SQL:** High-Performance Vectorized Querying (DuckDB, PostgreSQL), Multi-Step CTE Pipeline Architecture, Window Aggregations & Rolling Volatility, Vintage/Cohort Retention Modeling, Query Execution Optimization (WHERE Pushdown, Fan-Out Elimination).
# - **Machine Learning & Risk Analytics:** Unsupervised Anomaly Detection (Isolation Forests, K-Means), Risk Scoring Models, Model Interpretability (SHAP, LIME), Behavioral Pattern Recognition, Data Integrity Auditing.
# - **Data Engineering & Big Data Systems:** PySpark, Databricks Delta Lake, ETL/ELT Pipeline Development, Logical & Physical Schema Design, Multi-Source Data Merging, REST API Integrations.
# - **Developer Environment & MLOps:** Linux/Unix (WSL2, Bash Scripting), Containerization (Docker), Git Version Control (Branching, Squash-and-Merge Workflows), CI/CD Pipelines, Cloud Platforms.
# - **Business Intelligence & Reporting:** Interactive Dashboards (Power BI, Tableau), Technical Documentation, Executive & Stakeholder Reporting.
